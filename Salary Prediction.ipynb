# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
salary = pd.read_csv("salary.csv")

# %%
salary.head()
# Out:
#    Unnamed: 0                  Job Title Salary Estimate  \
# 0           0             Data Scientist       $53K-$91K
# 1           1  Healthcare Data Scientist      $63K-$112K
# 2           2             Data Scientist       $80K-$90K
# 3           3             Data Scientist       $56K-$97K
# 4           4             Data Scientist      $86K-$143K
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         742 non-null    int64
#  1   Job Title          742 non-null    object
#  2   Salary Estimate    742 non-null    object
#  3   Job Description    742 non-null    object
#  4   Rating             742 non-null    float64
#  5   Company Name       742 non-null    object
#  6   Location           742 non-null    object
#  7   Headquarters       742 non-null    object
#  8   Size               742 non-null    object
#  9   Founded            742 non-null    int64
#  10  Type of ownership  742 non-null    object
#  11  Industry           742 non-null    object
#  12  Sector             742 non-null    object
#  13  Revenue            742 non-null    object
#  14  Competitors        742 non-null    object
#  15  hourly             742 non-null    int64
# ...

# %%
salary.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# job_simp             0
# seniority            0
# desc_len             0
# num_comp             0
# dtype: int64

# %%
salary.describe()
# Out:
#        Unnamed: 0      Rating      Founded      hourly  employer_provided  \
# count  742.000000  742.000000   742.000000  742.000000         742.000000
# mean   370.500000    3.618868  1837.154987    0.032345           0.022911
# std    214.341239    0.801210   497.183763    0.177034           0.149721
# min      0.000000   -1.000000    -1.000000    0.000000           0.000000
# 25%    185.250000    3.300000  1939.000000    0.000000           0.000000
# 50%    370.500000    3.700000  1988.000000    0.000000           0.000000
# 75%    555.750000    4.000000  2007.000000    0.000000           0.000000
# max    741.000000    5.000000  2019.000000    1.000000           1.000000
#
#        min_salary  max_salary  avg_salary  same_state         age   python_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean    74.719677  128.149596  100.626011    0.557951   46.591644    0.528302
# ...

# %%
sns.countplot(x='Job Title', data=salary)
# Out:
# <AxesSubplot:xlabel='Job Title', ylabel='count'>

# %%
sns.countplot(x='Salary Estimate', data=salary)
# Out:
# <AxesSubplot:xlabel='Salary Estimate', ylabel='count'>

# %%
sns.heatmap(salary.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
columns = ['Unnamed: 0', 'Job Description', 'Rating', 'Company Name', 'Location', 'Headquarters', 'Founded', 'Type of ownership', 'Industry', 'Sector', 'Competitors', 'hourly', 'employer_provided', 'company_txt', 'job_state', 'same_state', 'age', 'job_simp', 'seniority', 'desc_len', 'num_comp', 'min_salary', 'max_salary', 'avg_salary']
salary.drop(columns, axis=1, inplace=True)

# %%
salary.head()
# Out:
#                    Job Title Salary Estimate                    Size  \
# 0             Data Scientist       $53K-$91K   501 to 1000 employees
# 1  Healthcare Data Scientist      $63K-$112K        10000+ employees
# 2             Data Scientist       $80K-$90K   501 to 1000 employees
# 3             Data Scientist       $56K-$97K  1001 to 5000 employees
# 4             Data Scientist      $86K-$143K     51 to 200 employees
#
#                       Revenue  python_yn  R_yn  spark  aws  excel
# 0         $50 to $100 million          1     0      0    0      1
# 1            $2 to $5 billion          1     0      0    0      0
# 2        $100 to $500 million          1     0      1    0      1
# 3  $500 million to $1 billion          1     0      0    0      0
# 4    Unknown / Non-Applicable          1     0      0    0      1

# %%
salary['Job Title'].value_counts()
# Out:
# Data Scientist                               131
# Data Engineer                                 53
# Senior Data Scientist                         34
# Data Analyst                                  15
# Senior Data Engineer                          14
#                                             ...
# Business Intelligence Analyst / Developer      1
# Data Scientist/ML Engineer                     1
# Customer Data Scientist/Sales Engineer         1
# R&D Sr Data Scientist                          1
# Staff Scientist                                1
# Name: Job Title, Length: 264, dtype: int64

# %%
salary['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable      203
# $10+ billion                  124
# $100 to $500 million           91
# $1 to $2 billion               60
# $500 million to $1 billion     57
# $50 to $100 million            46
# $25 to $50 million             40
# $2 to $5 billion               39
# $10 to $25 million             32
# $5 to $10 billion              19
# $5 to $10 million              18
# $1 to $5 million                8
# Less than $1 million            4
# Less than 1 million             1
# Name: Revenue, dtype: int64

# %%
salary['Salary Estimate'].value_counts()
# Out:
# $54K-$115K    6
# $49K-$113K    6
# $21-$34       6
# $86K-$143K    6
# $81K-$167K    5
#              ..
# $71K-$144K    1
# $37K-$68K     1
# $91K-$148K    1
# $55K-$99K     1
# $58K-$104K    1
# Name: Salary Estimate, Length: 416, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
data = salary['Job Title'].values
encoder = LabelEncoder()
encoder.fit(data)
encoded_data = encoder.transform(data)
salary['Job Title'] = encoded_data

# %% [markdown]
# The following are the different job titles used in the data:
#
# Ag Data Scientist is 0
#
# Analytics - Business Assurance Data Analyst is 1
#
# Analytics Consultant is 2
#
# Analytics Manager is 3
#
# Analytics Manager - Data Mart is 4
#
# Assistant Director/Director, Office of Data Science is 5
#
# Associate Data Analyst is 6
#
# Associate Data Analyst- Graduate Development Program is 7
#
# Associate Data Engineer is 8
#
# Associate Data Scientist/Computer Scientist is 9
#
# Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence is 10
#
# Associate Director/Director, Safety Scientist is 11
#
# Associate Environmental Scientist - Wildlife Biologist is 12
#
# Associate Machine Learning Engineer / Data Scientist May 2020 Undergrad is 13
#
# Associate Principal Scientist, Pharmacogenomics is 14
#
# Associate Research Scientist I (Protein Expression and Production) is 15
#
# Associate Scientist is 16
#
# Associate Scientist / Sr. Associate Scientist, Antibody Discovery is 17
#
# Associate Scientist, LC/MS Biologics is 18
#
# Associate Scientist/Scientist, Process Analytical Technology - Small Molecule Analytical Chemistry is 19
#
# Associate, Data Science, Internal Audit is 20
#
# BI & Platform Analytics Manager is 21
#
# Big Data Engineer is 22
#
# Big Data Engineer - Chicago - Future Opportunity is 23
#
# Business Data Analyst is 24
#
# Business Data Analyst, SQL is 25
#
# Business Intelligence Analyst / Developer is 26
#
# CONSULTANT– DATA ANALYTICS GROUP is 27
#
# Clinical Data Analyst is 28
#
# Clinical Data Scientist is 29
#
# Clinical Laboratory Scientist is 30
#
# Clinical Scientist, Clinical Development is 31
#
# College Hire - Data Scientist - Open to December 2019 Graduates is 32
#
# Computational Chemist/Data Scientist is 33
#
# Consultant - Analytics Consulting is 34
#
# Corporate Risk Data Analyst (SQL Based) - Milwaukee or is 35
#
# Customer Data Scientist is 36
#
# Customer Data Scientist/Sales Engineer is 37
#
# Customer Data Scientist/Sales Engineer (Bay is 38
#
# Data & Analytics Consultant (NYC) is 39
#
# Data Analyst is 40
#
# Data Analyst - Asset Management is 41
#
# Data Analyst / Scientist is 42
#
# Data Analyst 1, full-time contract worker for up to 12 months is 43
#
# Data Analyst 2 (Missionary Department) is 44
#
# Data Analyst Chemist - Quality System Contractor is 45
#
# Data Analyst Senior is 46
#
# Data Analyst, Performance Partnership is 47
#
# Data Analytics Manager is 48
#
# Data Analytics Project Manager is 49
#
# Data Architect / Data Modeler is 50
#
# Data Engineer is 51
#
# Data Engineer - Consultant (Charlotte Based) is 52
#
# Data Engineer - ETL is 53
#
# Data Engineer 4 - Contract is 54
#
# Data Engineer 5 - Contract (Remote) is 55
#
# Data Engineer I is 56
#
# Data Engineer I - Azure is 57
#
# Data Engineer, Data Engineering and Artifical Intelligence is 58
#
# Data Engineering Analyst is 59
#
# Data Management Specialist is 60
#
# Data Modeler is 61
#
# Data Modeler (Analytical Systems) is 62
#
# Data Modeler - Data Solutions Engineer is 63
#
# Data Operations Lead is 64
#
# Data Science Analyst is 65
#
# Data Science Engineer - Mobile is 66
#
# Data Science Manager is 67
#
# Data Science Project Manager is 68
#
# Data Scientist is 69
#
# Data Scientist (Actuary, FSA or ASA) is 70
#
# Data Scientist (Warehouse Automation) is 71
#
# Data Scientist - Algorithms & Inference is 72
#
# Data Scientist - Alpha Insights is 73
#
# Data Scientist - Bioinformatics is 74
#
# Data Scientist - Health Data Analytics is 75
#
# Data Scientist - Quantitative is 76
#
# Data Scientist - Research is 77
#
# Data Scientist - Sales is 78
#
# Data Scientist - Systems Engineering is 79
#
# Data Scientist / Machine Learning Expert is 80
#
# Data Scientist II is 81
#
# Data Scientist Manager is 82
#
# Data Scientist SR is 83
#
# Data Scientist in Artificial Intelligence Early Career is 84
#
# Data Scientist in Translational Medicine is 85
#
# Data Scientist, Office of Data Science is 86
#
# Data Scientist, Rice University is 87
#
# Data Scientist, Senior is 88
#
# Data Scientist/ML Engineer is 89
#
# Digital Health Data Scientist is 90
#
# Digital Marketing & ECommerce Data Analyst is 91
#
# Director - Data, Privacy and AI Governance is 92
#
# Director Data Science is 93
#
# Director II, Data Science - GRM Actuarial is 94
#
# Director II, Data Science - GRS Predictive Analytics is 95
#
# Director, Data Science is 96
#
# Director, Precision Medicine Clinical Biomarker Scientist is 97
#
# E-Commerce Data Analyst is 98
#
# ENVIRONMENTAL ENGINEER/SCIENTIST is 99
#
# Enterprise Architect, Data is 100
#
# Excel / VBA / SQL Data Analyst is 101
#
# Financial Data Analyst is 102
#
# Food Scientist - Developer is 103
#
# Foundational Community Supports Data Analyst is 104
#
# Geospatial Software Developer and Data Scientist is 105
#
# Healthcare Data Scientist is 106
#
# IT - Data Engineer II is 107
#
# IT Associate Data Analyst is 108
#
# Information Security Data Analyst is 109
#
# Insurance Data Scientist is 110
#
# Insurance Financial Data Analyst is 111
#
# Jr. Business Data Analyst is 112
#
# Jr. Data Scientist is 113
#
# Junior Data Analyst is 114
#
# Lead Big Data Engineer is 115
#
# Lead Data Analyst is 116
#
# Lead Data Engineer is 117
#
# Lead Data Engineer (Python) is 118
#
# Lead Data Scientist is 119
#
# Lead Health Data Analyst - Front End is 120
#
# MED TECH/LAB SCIENTIST - LABORATORY is 121
#
# MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB is 122
#
# Machine Learning Engineer is 123
#
# Machine Learning Engineer (NLP) is 124
#
# Machine Learning Engineer - Regulatory is 125
#
# Machine Learning Research Scientist is 126
#
# Manager of Data Science is 127
#
# Manager, Safety Scientist, Medical Safety & Risk Management is 128
#
# Managing Data Scientist/ML Engineer is 129
#
# Market Data Analyst is 130
#
# Marketing Data Analyst is 131
#
# Marketing Data Analyst, May 2020 Undergrad is 132
#
# Medical Lab Scientist is 133
#
# Medical Lab Scientist - MLT is 134
#
# Medical Laboratory Scientist is 135
#
# Medical Technologist / Clinical Laboratory Scientist is 136
#
# MongoDB Data Engineer II is 137
#
# PL Actuarial-Lead Data Scientist is 138
#
# PV Scientist is 139
#
# Pricipal Scientist Molecular and cellular biologist is 140
#
# Principal Data Engineer, Data Platform & Insights is 141
#
# Principal Data Scientist is 142
#
# Principal Data Scientist (Computational Chemistry) is 143
#
# Principal Data Scientist with over 10 years experience is 144
#
# Principal Machine Learning Scientist is 145
#
# Principal Research Scientist/Team Lead, Medicinal Chemistry - Oncology is 146
#
# Principal Scientist - Immunologist is 147
#
# Principal Scientist, Chemistry & Immunology is 148
#
# Principal Scientist, Hematology is 149
#
# Principal, Data Science - Advanced Analytics is 150
#
# Product Engineer – Data Science is 151
#
# Product Engineer – Spatial Data Science and Statistical Analysis is 152
#
# Product Manager/Data Evangelist is 153
#
# Products Data Analyst II is 154
#
# Program/Data Analyst is 155
#
# Project Scientist is 156
#
# Project Scientist - Auton Lab, Robotics Institute is 157
#
# Quality Control Scientist III- Analytical Development is 158
#
# R&D Data Analysis Scientist is 159
#
# R&D Specialist/ Food Scientist is 160
#
# R&D Sr Data Scientist is 161
#
# RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEER - SR. COMPUTER SCIENTIST - SOFTWARE DEVELOPMENT is 162
#
# RESEARCH SCIENTIST - BIOLOGICAL SAFETY is 163
#
# Radar Data Analyst is 164
#
# Research Scientist is 165
#
# Research Scientist / Principal Research Scientist - Multiphysical Systems is 166
#
# Research Scientist or Senior Research Scientist - Computer Vision is 167
#
# Research Scientist – Security and Privacy is 168
#
# Research Scientist, Immunology - Cancer Biology is 169
#
# Research Scientist, Machine Learning Department is 170
#
# Revenue Analytics Manager is 171
#
# Risk and Analytics IT, Data Scientist is 172
#
# SQL Data Engineer is 173
#
# Salesforce Analytics Consultant is 174
#
# Scientist is 175
#
# Scientist - Analytical Services is 176
#
# Scientist - Biomarker and Flow Cytometry is 177
#
# Scientist - CVRM Metabolism - in vivo pharmacology is 178
#
# Scientist 2, QC Viral Vector is 179
#
# Scientist I/II, Biology is 180
#
# Scientist Manufacturing - Kentucky BioProcessing is 181
#
# Scientist Manufacturing Pharma - Kentucky BioProcessing is 182
#
# Scientist – Cancer Discovery, Molecular Assay is 183
#
# Scientist, Analytical Development is 184
#
# Scientist, Bacteriology is 185
#
# Scientist, Immuno-Oncology is 186
#
# Scientist, Molecular/Cellular Biologist is 187
#
# Scientist, Pharmacometrics is 188
#
# Scientist/Senior Scientist, Autoimmune is 189
#
# Senior Data & Machine Learning Scientist is 190
#
# Senior Data Analyst is 191
#
# Senior Data Analyst/Scientist is 192
#
# Senior Data Engineer is 193
#
# Senior Data Science Systems Engineer is 194
#
# Senior Data Scientist is 195
#
# Senior Data Scientist - Algorithms is 196
#
# Senior Data Scientist - R&D Oncology is 197
#
# Senior Data Scientist / Machine Learning is 198
#
# Senior Data Scientist 4 Artificial Intelligence is 199
#
# Senior Data Scientist Artificial Intelligence is 200
#
# Senior Data Scientist Oncology is 201
#
# Senior Data Scientist Statistics is 202
#
# Senior Data Scientist – Visualization, Novartis AI Innovation Lab is 203
#
# Senior Data Scientist: Causal & Predictive analytics AI Innovation Lab is 204
#
# Senior Engineer, Data Management Engineering is 205
#
# Senior Formulations Scientist II is 206
#
# Senior Health Data Analyst, Star Ratings is 207
#
# Senior Insurance Data Scientist is 208
#
# Senior LiDAR Data Scientist is 209
#
# Senior Machine Learning (ML) Engineer / Data Scientist - Cyber Security Analytics is 210
#
# Senior Manager, Epidemiologic Data Scientist is 211
#
# Senior Operations Data Analyst, Call Center Operations is 212
#
# Senior Quantitative Analyst is 213
#
# Senior Research Analytical Scientist-Non-Targeted Analysis is 214
#
# Senior Research Scientist - Embedded System Development for DevOps is 215
#
# Senior Research Scientist-Machine Learning is 216
#
# Senior Research Statistician- Data Scientist is 217
#
# Senior Risk Data Scientist is 218
#
# Senior Scientist (Neuroscience) is 219
#
# Senior Scientist - Biostatistician is 220
#
# Senior Scientist - Neuroscience is 221
#
# Senior Scientist - Regulatory Submissions is 222
#
# Senior Scientist - Toxicologist - Product Integrity (Stewardship) is 223
#
# Senior Scientist, Cell Pharmacology/Assay Development is 224
#
# Senior Spark Engineer (Data Science) is 225
#
# Software Data Engineer - College is 226
#
# Software Engineer (Data Scientist/Software Engineer) - SISW - MG is 227
#
# Software Engineer - Data Visualization is 228
#
# Software Engineer Staff Scientist: Human Language Technologies is 229
#
# Spectral Scientist/Engineer is 230
#
# Sr Data Analyst - IT is 231
#
# Sr Data Engineer (Sr BI Developer) is 232
#
# Sr Expert Data Science, Advanced Visual Analytics (Associate level) is 233
#
# Sr Scientist, Immuno-Oncology - Oncology is 234
#
# Sr Software Engineer (Data Scientist) is 235
#
# Sr. Data Analyst is 236
#
# Sr. Data Engineer is 237
#
# Sr. Data Engineer (ETL Developer) is 238
#
# Sr. Data Engineer - Contract-to-Hire (Java) is 239
#
# Sr. Data Engineer | Big Data SaaS Pipeline is 240
#
# Sr. Data Scientist is 241
#
# Sr. Data Scientist - Analytics, Personalized Healthcare (PHC) is 242
#
# Sr. Data Scientist II is 243
#
# Sr. Data Scientist, Cyber-Security LT Contract is 244
#
# Sr. Scientist - Digital & Image Analysis/Computational Pathology is 245
#
# Sr. Scientist II is 246
#
# Sr. Scientist Method Development is 247
#
# Sr. Scientist, Quantitative Translational Sciences is 248
#
# Staff BI and Data Engineer is 249
#
# Staff Data Engineer is 250
#
# Staff Data Scientist is 251
#
# Staff Data Scientist - Technology is 252
#
# Staff Machine Learning Engineer is 253
#
# Staff Scientist is 254
#
# Staff Scientist- Upstream PD is 255
#
# Staff Scientist-Downstream Process Development is 256
#
# Supply Chain Data Analyst is 257
#
# Survey Data Analyst is 258
#
# System and Data Analyst is 259
#
# Systems Engineer II - Data Analyst is 260
#
# Technology-Minded, Data Professional Opportunities is 261
#
# VP, Data Science is 262
#
# Web Data Analyst is 263

# %%
from sklearn.preprocessing import LabelEncoder
data1 = salary['Revenue'].values
encoder1 = LabelEncoder()
encoded_data1 = encoder1.fit_transform(data1)
salary['Revenue'] = encoded_data1

# %% [markdown]
# The following are different revenue made by the company where you work:
#
# - $1 to $2 billion is 0
#
# - $1 to $5 million is 1
#
# - $10 to $25 million is 2
#
# - $10+ billion is 3
#
# - $100 to $500 million is 4
#
# - $2 to $5 billion is 5
#
# - $25 to $50 million is 6
#
# - $5 to $10 billion is 7
#
# - $5 to $10 million is 8
#
# - $50 to $100 million is 9
#
# - $500 million to $1  billion is 10
#
# - Less than $1 million is 11
#
# - Less than 1 million is 12
#
# - Unknown / Non-Applicable is 13

# %%
from sklearn.preprocessing import LabelEncoder
data2 = salary['Salary Estimate']
encoder2 = LabelEncoder()
encoded_data2 = encoder2.fit_transform(data2)
salary['Salary Estimate'] = encoded_data2

# %%
from sklearn.preprocessing import LabelEncoder
data3 = salary['Size'].values
encoder3 = LabelEncoder()
encoder3.fit(data3)
encoded_data3 = encoder3.transform(data3)
salary['Size'] = encoded_data3

# %% [markdown]
# The following are the different sizes of companies used in the data and their value:
#
# 1 to 50 employees is 0
#
# 10000+ employees is 1
#
# 1001 to 5000 employees is 2
#
# 201 to 500 employees is 3
#
# 5001 to 10000 employees is 4
#
# 501 to 1000 employees is 5
#
# 51 to 200 employees is 6
#
# More than 10000 employees is 7
#
# Unknown is 8

# %%
X = salary.drop('Salary Estimate', axis=1)
y = salary['Salary Estimate']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
model = make_pipeline(StandardScaler(), LogisticRegression())
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train = train_test_split(X,y,test_size=0.3,random_state=42)
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
X_train_prediction=model.predict(X_train)
from sklearn.metrics import accuracy_score
training_data_accuracy=accuracy_score(y_train,X_train_prediction)
print("Accuracy score of data:",training_data_accuracy * 100)
# Out:
# Accuracy score of data: 47.53363228699551

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        742 non-null    int32
#  1   Salary Estimate  742 non-null    int32
#  2   Size             742 non-null    int32
#  3   Revenue          742 non-null    int32
#  4   python_yn        742 non-null    int64
#  5   R_yn             742 non-null    int64
#  6   spark            742 non-null    int64
#  7   aws              742 non-null    int64
#  8   excel            742 non-null    int64
# dtypes: int32(4), int64(5)
# memory usage: 40.7 KB

# %%
Salary_Estimate = [float(input("What is your Job Title?: ")), float(input("How many employees does your company have?: ")), float(input("How much does your compay earn in a year: ")), float(input("Do you have knowledge on python? Yes[1] or No[0]: ")), float(input("Do you have knowledge on R? Yes[1] or No[0]: ")), float(input("Can you use Spark Yes[1] or No[0]: ")), float(input("Can you use Amazon Web Services(AWS) Yes[1] or No[0]: ")), float(input("Can you use Microsoft Excel Yes[1] or No[0]: "))]
Salary = np.asarray(Salary_Estimate)
sal = Salary.reshape(-1, 8)
pay = model.predict(sal)
predicted_data = encoder2.inverse_transform(pay)
for i in range(len(pay)):
    print('....')
    print(f"I predict that you should be earning {predicted_data[i]} per month")
# Out:
# What is your Job Title?: 1
# How many employees does your company have?: 1
# How much does your compay earn in a year: 1
# Do you have knowledge on python? Yes[1] or No[0]: 1
# Do you have knowledge on R? Yes[1] or No[0]: 1
# Can you use Spark Yes[1] or No[0]: 1
# Can you use Amazon Web Services(AWS) Yes[1] or No[0]: 1
# Can you use Microsoft Excel Yes[1] or No[0]: 1
# ....
# I predict that you should be earning $79K-$147K per month
